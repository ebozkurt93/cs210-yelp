# %%
import os
import numpy as np
import pandas as pd

import re
import nltk
from nltk.corpus import stopwords

dataset_location = "dataset" # change this if needed, it is assumed that all the csv files are inside that folder.

# %% [markdown]
# ### ML fikirler
# * Sentiment analysis
# * Uzaklık vb bakarak restoran rating tahmini

# %% [markdown]
# Uzaklık vb bakarak restoran rating tahmini (las vegas)
# * review text
# * business id
# *

# %%
# %%time
df_review = pd.read_pickle(os.path.join(dataset_location, "yelp_review.pickle"))
df_business = pd.read_csv(os.path.join(dataset_location, "yelp_business.csv"))
# Out:
# Wall time: 1min 3s

# %%
df_review
# Out:
#                       review_id                 user_id  \
# 0        vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw
# 1        n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw
# 2        MV3CcKScW05u5LVfF6ok0g  bv2nCi5Qv5vroFiqKGopiw
# 3        IXvOzsEMYtiJI0CARmj77Q  bv2nCi5Qv5vroFiqKGopiw
# 4        L_9BTb55X0GDtThi6GlZ6w  bv2nCi5Qv5vroFiqKGopiw
# 5        HRPm3vEZ_F-33TYVT7Pebw  _4iMDXbXZ1p1ONG297YEAQ
# 6        ymAUG8DZfQcFTBSOiaNN4w  u0LXt3Uea_GidxRW1xcsfg
# 7        8UIishPUD92hXtScSga_gw  u0LXt3Uea_GidxRW1xcsfg
# 8        w41ZS9shepfO3uEyhXEWuQ  u0LXt3Uea_GidxRW1xcsfg
# 9        WF_QTN3p-thD74hqpp2j-Q  u0LXt3Uea_GidxRW1xcsfg
# 10       PIsUSmvaUWB00qv5KTF1xA  u0LXt3Uea_GidxRW1xcsfg
# 11       PdZ_uFjbbkjtm3SCY_KrZw  u0LXt3Uea_GidxRW1xcsfg
# 12       x5oV6wm9_Pb1QQ6jkjDjwQ  u0LXt3Uea_GidxRW1xcsfg
# 13       lsoSqIrrDbQvWpMvsSj2xw  u0LXt3Uea_GidxRW1xcsfg
# 14       23eqwlZzCWZkADWfd9atZw  u0LXt3Uea_GidxRW1xcsfg
# 15       FunI9om-aK5oMIIJmhMlZA  u0LXt3Uea_GidxRW1xcsfg
# ...

# %%
df_business
# Out:
#                    business_id  \
# 0       FYWN1wneV18bWNgQjJ2GNg
# 1       He-G7vWjzVUysIKrfNbPUQ
# 2       KQPW8lFf1y5BT2MxiSZ3QA
# 3       8DShNS-LuFqpEWIp0HxijA
# 4       PfOCPjBrlQAnz__NXj9h_w
# 5       o9eMRCWt5PkpLDE0gOPtcQ
# 6       kCoE3jvEtg6UVz5SOD3GVw
# 7       OD2hnuuTJI9uotcKycxg1A
# 8       EsMcGiZaQuG1OOvL9iUFug
# 9       TGWhGNusxyMaA4kQVBNeew
# 10      XOSRcvtaKc_Q5H1SAzN20A
# 11      Y0eMNa5C-YU1RQOZf9XvVA
# 12      xcgFnd-MwkZeO5G2HQ0gAQ
# 13      NmZtoE3v8RdSJEczYbMT9g
# 14      fNMVV_ZX7CJSDWQGdOM8Nw
# 15      l09JfMeQ6ynYs5MCJtrcmQ
# 16      IQSlT5jGE6CCDhSG0zG3xg
# 17      b2I2DXtZVnpUMCXp1JON7A
# 18      0FMKDOU8TJT1x87OKYGDTg
# 19      Gu-xs3NIQTj3Mj2xYoN2aw
# 20      lHYiCS-y8AFjUitv6MGpxg
# 21      94KziT6DQ9XlBET3WzIv_w
# 22      7YIy1tXOor9VCwvaSjuBHg
# 23      PMH4oUa-bWELKogdtkWewg
# 24      VSGcuYDV3q-AAZ9ZPq4fBQ
# 25      1K4qrnfyzKzGgJPBEcJaNQ
# 26      VBHEsoXQb2AQ76J9l8h1uQ
# 27      AtdXq_gu9NTE5rx4ct_dGg
# 28      Dj0S-Oe4ytRJzMGUPgYUkw
# ...

# %%
df_business[df_business['city'] == 'Las Vegas']
# Out:
#                    business_id  \
# 6       kCoE3jvEtg6UVz5SOD3GVw
# 7       OD2hnuuTJI9uotcKycxg1A
# 26      VBHEsoXQb2AQ76J9l8h1uQ
# 41      1Jp_hmPNUZArNqzpbm7B0g
# 48      DPQnTnNw2PJj7DdENM98Cw
# 49      _F3AMoo_zdl-he384ISQbw
# 52      Pd52CjgyEU3Rb8co6QfTPw
# 53      4srfPk1s8nlm1YusyDUbjg
# 54      n7V4cD-KqqE3OXk0irJTyA
# 59      Sx0C2RsDgrG3RxBBUoBqTw
# 60      v2GJWvZqEAjUc22hZUYzYw
# 61      MmR06_kNAbmOPK-0pKvGtA
# 82      bOOgAB_CEWWsxalAthnRSw
# 83      l5ijDMpYdyKbF0CxiCVO_Q
# 91      F0fEKpTk7gAmuSFI0KW1eQ
# 108     d2HSFutxpaYsCPglJPRe1Q
# 110     ZmMCgM4RCqCXJ0Lswu6yxw
# 112     pR6Fy9cP3oAzM_DtloLV5w
# 115     oB5KH-jYU93w-QnHas6EMA
# 122     Wpt0sFHcPtV5MO9He7yMKQ
# 123     ZvvX30vgzBD2Ezd1zM33IQ
# 124     0953KSZ26LmJ7CDacVzpYg
# 125     DAG8irsIf0hMsEgDbrOE_A
# 133     W1Yr6c2XDx_RBjb6WsV-aQ
# 136     OcUVZniPo7CnIG-Tv83XcQ
# 139     EXsmUB2mJyJsCpCV-56Ujw
# 140     NC03ZDFpIYpEi2aiFTmGPg
# 145     vzx1WdVivFsaN4QYrez2rw
# 150     aWnASLfWj1G6ptH4SR5RRA
# ...

# %%
t = df_review[df_review['business_id'].isin(list(df_business[df_business['city'] == 'Las Vegas']['business_id']))]

# %%
df_business[df_business['name'] == '"Mon Ami Gabi"'] #business_id 4JNXUYY8wbaaDmk3BPzlWw
# Out:
#                   business_id            name neighborhood  \
# 97944  4JNXUYY8wbaaDmk3BPzlWw  "Mon Ami Gabi"    The Strip
#
#                        address       city state postal_code   latitude  \
# 97944  "3655 Las Vegas Blvd S"  Las Vegas    NV       89109  36.112827
#
#         longitude  stars  review_count  is_open  \
# 97944 -115.172581    4.0          7361        1
#
#                                               categories
# 97944  French;Steakhouses;Restaurants;Breakfast & Brunch

# %%
mon_ami = t[t['business_id'] == '4JNXUYY8wbaaDmk3BPzlWw']

# %%
mon_ami = mon_ami.reset_index()

# %%
mon_ami
# Out:
#         index               review_id                 user_id  \
# 0        1720  YCzBgTYCyTtPAe2v8_GGKA  CZs1Eq7t1fqpXV1yox-CVg
# 1        2399  lPf1wwTu9VeWABHDPhu2tA  Zqk-ye_OHeH_sS1JsdsLgg
# 2        3430  voVb586hGvZC6vUA7HUIIw  RmThjWcv7x5Z_vVuOlRNwQ
# 3        7921  jipTZe7L20v422d2Di2_Tw  hBl_w9Rmn_Bz0HiMzwaknA
# 4        8793  D5r-QLswHpnxaMadQdi_dg  eZ5I1bHkdXoGOFKn_oOFFQ
# 5        9069  hBP7vFWMZ7k39lXPVdKinA  TDFkVg2kyY4ICVu6TPBnZg
# 6       10342  KHBsVX2TJVSJertyhY-x2Q  SuyRUCI27QjQnQk7RNCu6Q
# 7       10411  bMcaOZBOhObOvq8sMqYyzg  YAK6gbuqYey8SCphsZbK_w
# 8       14913  wzlvWdffdRPjrXESj84Wuw  JXHrhT72U6sZJQSkFfNzjw
# 9       15182  c5sZcUAXIASWmXyClb0X0Q  DK9eq2zjoESaXpXK7zZIUw
# 10      15917  y_jfI29Ed-cJ3OGO2aGZgw  zXElBzIpoR7iisptOcs1jQ
# 11      16557  JKp_essDu3SEX_G8jNfgtA  -j_IieSxPtLgds9ofQUbKQ
# 12      16610  cqkmou34WzJdWudGY9D8jQ  CFyvX-AZh6cunAMu_zoF_w
# 13      17705  O-6I4ISFE02n7411MQOygQ  PGJ4eb-8tmvea3XzqIdc_Q
# ...

# %%
temp = mon_ami[['stars', 'text']]

# %%
temp
# Out:
#       stars                                               text
# 0         4  Traditional French fare at the heart of the La...
# 1         5  This is my go to place for the last 12 years, ...
# 2         2  Mediocre food for too much money, at least at ...
# 3         4  My family and I had dinner here and the wait w...
# 4         5  Patio dining at its best. Steak au poive with ...
# 5         2  I ordered a rare ribeye steak and got an almos...
# 6         5  This review is long overdue.  I have a meal at...
# 7         5  My wife and I loved it.  It was a date night f...
# 8         3  Had lunch at Mon Ami Gabi on a Friday afternoo...
# 9         4  My review is for breakfast. They take reservat...
# 10        4  LOVE this place - get a seat outside for a vie...
# 11        2  We had reservations, but could not sit on pati...
# 12        5  I'm not sure how much this 1003rd review can a...
# 13        4  Located next to the Eiffel tower and across th...
# ...

# %%
def preprocess(text, stop_words):
    text = re.sub(r'[^\w]', ' ', text) #remove special chars
    temp = [x.lower() for x in text.split()] #lower all
    temp = [x for x in temp if x not in stop_words] #remove stop words
    #temp = []
    return temp

# %%
stop_words = set(stopwords.words('english'))
preprocess(s, stop_words)
# Out:
# Traditional French fare at the heart of the Las Vegas Strip that never fails to satisfy   Whether you re a regular or virgin at Mon Ami Gabi please make sure you save room for dessert   Perhaps do what I ve done  just make the dining experience a dessert filled table    made from scratch and sinfully delicious desserts   Yes  I have a sweet tooth  have you not seen my pictures    I ve dined here numerous times over the years  yes Food and not only dessert    Onion soup  steak frites and those mussels mariniere  The mussels  I have will power and have the half order  Yes  half so I can clearly utilize that doughy stuff by scooping up the white wine   herbs broth    You can t go wrong with pretty much anything the menu offers  so peruse that menu and order away
# ['traditional',
#  'french',
#  'fare',
#  'at',
#  'the',
#  'heart',
#  'of',
#  'the',
#  'las',
#  'vegas',
#  'strip',
#  'that',
#  'never',
#  'fails',
#  'to',
#  'satisfy',
#  'whether',
#  'you',
#  're',
#  'a',
# ...

# %%
for i, row in temp.iterrows():
    print (row['text'])
    break
# Out:
# Traditional French fare at the heart of the Las Vegas Strip that never fails to satisfy.  Whether you're a regular or virgin at Mon Ami Gabi please make sure you save room for dessert.  Perhaps do what I've done, just make the dining experience a dessert filled table;)  made from scratch and sinfully delicious desserts.  Yes, I have a sweet tooth- have you not seen my pictures!
# I've dined here numerous times over the years, yes Food and not only dessert.
# Onion soup, steak frites and those mussels mariniere! The mussels, I have will power and have the half order. Yes, half so I can clearly utilize that doughy stuff by scooping up the white wine & herbs broth:)
# You can't go wrong with pretty much anything the menu offers, so peruse that menu and order away!

# %%
s
# Out:
# "Traditional French fare at the heart of the Las Vegas Strip that never fails to satisfy.  Whether you're a regular or virgin at Mon Ami Gabi please make sure you save room for dessert.  Perhaps do what I've done, just make the dining experience a dessert filled table;)  made from scratch and sinfully delicious desserts.  Yes, I have a sweet tooth- have you not seen my pictures!  \nI've dined here numerous times over the years, yes Food and not only dessert.  \nOnion soup, steak frites and those mussels mariniere! The mussels, I have will power and have the half order. Yes, half so I can clearly utilize that doughy stuff by scooping up the white wine & herbs broth:) \nYou can't go wrong with pretty much anything the menu offers, so peruse that menu and order away!"
